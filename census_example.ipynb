# %%
from pytorch_tabnet.tab_model import TabNetClassifier

import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score

import pandas as pd
import numpy as np
np.random.seed(0)

import scipy

import os
import wget
from pathlib import Path

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import os
os.chdir(r"D:\Git_repos\tabnet")
os.environ['CUDA_VISIBLE_DEVICES'] = f"1"

# %%
import torch
torch.__version__
# Out:
# '2.7.0+cu128'

# %% [markdown]
# # Download census-income dataset

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
dataset_name = 'census-income'
out = Path(os.getcwd()+'/data/'+dataset_name+'.csv')

# %%
out.parent.mkdir(parents=True, exist_ok=True)
if out.exists():
    print("File already exists.")
else:
    print("Downloading file...")
    wget.download(url, out.as_posix())
# Out:
# Downloading file...
# -1 / unknown

# %% [markdown]
# # Load data and split

# %%
train = pd.read_csv(out)
target = ' <=50K'
if "Set" not in train.columns:
    train["Set"] = np.random.choice(["train", "valid", "test"], p =[.8, .1, .1], size=(train.shape[0],))

train_indices = train[train.Set=="train"].index
valid_indices = train[train.Set=="valid"].index
test_indices = train[train.Set=="test"].index

# %% [markdown]
# # Simple preprocessing
#
# Label encode categorical features and fill empty cells.

# %%
nunique = train.nunique()
types = train.dtypes

categorical_columns = []
categorical_dims =  {}
for col in train.columns:
    if types[col] == 'object' or nunique[col] < 200:
        print(col, train[col].nunique())
        l_enc = LabelEncoder()
        train[col] = train[col].fillna("VV_likely")
        train[col] = l_enc.fit_transform(train[col].values)
        categorical_columns.append(col)
        categorical_dims[col] = len(l_enc.classes_)
    else:
        train.fillna(train.loc[train_indices, col].mean(), inplace=True)
# Out:
# 39 73
#  State-gov 9
#  Bachelors 16
#  13 16
#  Never-married 7
#  Adm-clerical 15
#  Not-in-family 6
#  White 5
#  Male 2
#  2174 119
#  0 92
#  40 94
#  United-States 42
#  <=50K 2
# Set 3

# %%
# check that pipeline accepts strings
train.loc[train[target]==0, target] = "wealthy"
train.loc[train[target]==1, target] = "not_wealthy"
# Out:
# C:\Users\Farshad\AppData\Local\Temp\ipykernel_12800\674795864.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'wealthy' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train.loc[train[target]==0, target] = "wealthy"

# %% [markdown]
# # Define categorical features for categorical embeddings

# %%
unused_feat = ['Set']

features = [ col for col in train.columns if col not in unused_feat+[target]] 

cat_idxs = [ i for i, f in enumerate(features) if f in categorical_columns]

cat_dims = [ categorical_dims[f] for i, f in enumerate(features) if f in categorical_columns]

# %% [markdown]
# # Grouped features
#
# You can now specify groups of feature which will share a common attention.
#
# This may be very usefull for features comming from a same preprocessing technique like PCA for example.

# %%
len(features)
# Out:
# 14

# %%
grouped_features = [[0, 1, 2], [8, 9, 10]]

# %% [markdown]
# # Network parameters

# %%
tabnet_params = {"cat_idxs":cat_idxs,
                 "cat_dims":cat_dims,
                 "cat_emb_dim":2,
                 "optimizer_fn":torch.optim.Adam,
                 "optimizer_params":dict(lr=2e-2),
                 "scheduler_params":{"step_size":50, # how to use learning rate scheduler
                                 "gamma":0.9},
                 "scheduler_fn":torch.optim.lr_scheduler.StepLR,
                 "mask_type":'entmax', # "sparsemax"
                 "grouped_features" : grouped_features
                }

clf = TabNetClassifier(**tabnet_params
                      )
# Out:
# D:\venvs\venv1\Lib\site-packages\pytorch_tabnet\abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")

# %% [markdown]
# # Training

# %%
X_train = train[features].values[train_indices]
y_train = train[target].values[train_indices]

X_valid = train[features].values[valid_indices]
y_valid = train[target].values[valid_indices]

X_test = train[features].values[test_indices]
y_test = train[target].values[test_indices]

# %%
max_epochs = 50 if not os.getenv("CI", False) else 2

# %%
from pytorch_tabnet.augmentations import ClassificationSMOTE
aug = ClassificationSMOTE(p=0.2)

# %%
# This illustrates the behaviour of the model's fit method using Compressed Sparse Row matrices
sparse_X_train = scipy.sparse.csr_matrix(X_train)  # Create a CSR matrix from X_train
sparse_X_valid = scipy.sparse.csr_matrix(X_valid)  # Create a CSR matrix from X_valid

# Fitting the model
clf.fit(
    X_train=sparse_X_train, y_train=y_train,
    eval_set=[(sparse_X_train, y_train), (sparse_X_valid, y_valid)],
    eval_name=['train', 'valid'],
    eval_metric=['auc'],
    max_epochs=max_epochs , patience=20,
    batch_size=1024, virtual_batch_size=128,
    num_workers=0,
    weights=1,
    drop_last=False,
    augmentations=aug, #aug, None
)
# Out:
# epoch 0  | loss: 0.57776 | train_auc: 0.78953 | valid_auc: 0.80104 |  0:00:03s
# epoch 1  | loss: 0.4741  | train_auc: 0.85843 | valid_auc: 0.86845 |  0:00:07s
# epoch 2  | loss: 0.45059 | train_auc: 0.87337 | valid_auc: 0.88348 |  0:00:10s
# epoch 3  | loss: 0.43497 | train_auc: 0.8908  | valid_auc: 0.89643 |  0:00:14s
# epoch 4  | loss: 0.42716 | train_auc: 0.89811 | valid_auc: 0.90135 |  0:00:17s
# epoch 5  | loss: 0.41261 | train_auc: 0.9061  | valid_auc: 0.90944 |  0:00:20s
# epoch 6  | loss: 0.39464 | train_auc: 0.91141 | valid_auc: 0.91544 |  0:00:24s
# epoch 7  | loss: 0.38969 | train_auc: 0.91788 | valid_auc: 0.92095 |  0:00:27s
# epoch 8  | loss: 0.38398 | train_auc: 0.92066 | valid_auc: 0.92111 |  0:00:30s
# epoch 9  | loss: 0.38027 | train_auc: 0.92119 | valid_auc: 0.92236 |  0:00:34s
# epoch 10 | loss: 0.37562 | train_auc: 0.92498 | valid_auc: 0.92262 |  0:00:37s
# epoch 11 | loss: 0.37409 | train_auc: 0.92717 | valid_auc: 0.92292 |  0:00:41s
# epoch 12 | loss: 0.37504 | train_auc: 0.92821 | valid_auc: 0.92398 |  0:00:44s
# epoch 13 | loss: 0.35996 | train_auc: 0.92726 | valid_auc: 0.9241  |  0:00:48s
# epoch 14 | loss: 0.36747 | train_auc: 0.92988 | valid_auc: 0.92381 |  0:00:51s
# epoch 15 | loss: 0.36514 | train_auc: 0.93077 | valid_auc: 0.92592 |  0:00:54s
# epoch 16 | loss: 0.3584  | train_auc: 0.93078 | valid_auc: 0.92548 |  0:00:57s
# epoch 17 | loss: 0.36318 | train_auc: 0.93142 | valid_auc: 0.92462 |  0:01:01s
# epoch 18 | loss: 0.36245 | train_auc: 0.9326  | valid_auc: 0.92568 |  0:01:04s
# epoch 19 | loss: 0.3637  | train_auc: 0.93259 | valid_auc: 0.9263  |  0:01:07s
# epoch 20 | loss: 0.36058 | train_auc: 0.93208 | valid_auc: 0.92522 |  0:01:11s
# epoch 21 | loss: 0.35644 | train_auc: 0.93345 | valid_auc: 0.92668 |  0:01:14s
# epoch 22 | loss: 0.35831 | train_auc: 0.9339  | valid_auc: 0.92681 |  0:01:18s
# epoch 23 | loss: 0.36176 | train_auc: 0.93377 | valid_auc: 0.92643 |  0:01:21s
# epoch 24 | loss: 0.3552  | train_auc: 0.9354  | valid_auc: 0.92644 |  0:01:25s
# epoch 25 | loss: 0.35704 | train_auc: 0.93527 | valid_auc: 0.92544 |  0:01:29s
# epoch 26 | loss: 0.35412 | train_auc: 0.9354  | valid_auc: 0.92624 |  0:01:32s
# epoch 27 | loss: 0.35326 | train_auc: 0.93608 | valid_auc: 0.9252  |  0:01:36s
# epoch 28 | loss: 0.35479 | train_auc: 0.93484 | valid_auc: 0.92769 |  0:01:39s
# epoch 29 | loss: 0.35652 | train_auc: 0.93459 | valid_auc: 0.92543 |  0:01:43s
# epoch 30 | loss: 0.35538 | train_auc: 0.93673 | valid_auc: 0.92377 |  0:01:46s
# epoch 31 | loss: 0.35797 | train_auc: 0.93625 | valid_auc: 0.92473 |  0:01:50s
# epoch 32 | loss: 0.34968 | train_auc: 0.93762 | valid_auc: 0.92474 |  0:01:53s
# epoch 33 | loss: 0.35159 | train_auc: 0.93803 | valid_auc: 0.9232  |  0:01:57s
# epoch 34 | loss: 0.35144 | train_auc: 0.93623 | valid_auc: 0.92528 |  0:02:00s
# epoch 35 | loss: 0.34918 | train_auc: 0.93849 | valid_auc: 0.92487 |  0:02:04s
# epoch 36 | loss: 0.34984 | train_auc: 0.93809 | valid_auc: 0.92549 |  0:02:07s
# epoch 37 | loss: 0.35102 | train_auc: 0.93859 | valid_auc: 0.92416 |  0:02:10s
# epoch 38 | loss: 0.35272 | train_auc: 0.93952 | valid_auc: 0.92469 |  0:02:14s
# epoch 39 | loss: 0.34767 | train_auc: 0.93754 | valid_auc: 0.92185 |  0:02:17s
# epoch 40 | loss: 0.347   | train_auc: 0.93938 | valid_auc: 0.92638 |  0:02:20s
# epoch 41 | loss: 0.34852 | train_auc: 0.93992 | valid_auc: 0.92406 |  0:02:23s
# epoch 42 | loss: 0.35169 | train_auc: 0.9399  | valid_auc: 0.92302 |  0:02:27s
# epoch 43 | loss: 0.35226 | train_auc: 0.9391  | valid_auc: 0.92246 |  0:02:30s
# epoch 44 | loss: 0.34329 | train_auc: 0.94007 | valid_auc: 0.9223  |  0:02:33s
# epoch 45 | loss: 0.34972 | train_auc: 0.93986 | valid_auc: 0.92246 |  0:02:37s
# epoch 46 | loss: 0.34592 | train_auc: 0.9398  | valid_auc: 0.9244  |  0:02:40s
# epoch 47 | loss: 0.34325 | train_auc: 0.94075 | valid_auc: 0.92254 |  0:02:43s
# epoch 48 | loss: 0.35086 | train_auc: 0.9402  | valid_auc: 0.92025 |  0:02:47s
#
# Early stopping occurred at epoch 48 with best_epoch = 28 and best_valid_auc = 0.92769
# D:\venvs\venv1\Lib\site-packages\pytorch_tabnet\callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
# This illustrates the warm_start=False behaviour
save_history = []

# Fitting the model without starting from a warm start nor computing the feature importance
for _ in range(2):
    clf.fit(
        X_train=X_train, y_train=y_train,
        eval_set=[(X_train, y_train), (X_valid, y_valid)],
        eval_name=['train', 'valid'],
        eval_metric=['auc'],
        max_epochs=max_epochs , patience=20,
        batch_size=1024, virtual_batch_size=128,
        num_workers=0,
        weights=1,
        drop_last=False,
        augmentations=aug, #aug, None
        compute_importance=False
    )
    save_history.append(clf.history["valid_auc"])

assert(np.all(np.array(save_history[0]==np.array(save_history[1]))))

save_history = []  # Resetting the list to show that it also works when computing feature importance

# Fitting the model without starting from a warm start but with the computing of the feature importance activated
for _ in range(2):
    clf.fit(
        X_train=X_train, y_train=y_train,
        eval_set=[(X_train, y_train), (X_valid, y_valid)],
        eval_name=['train', 'valid'],
        eval_metric=['auc'],
        max_epochs=max_epochs , patience=20,
        batch_size=1024, virtual_batch_size=128,
        num_workers=0,
        weights=1,
        drop_last=False,
        augmentations=aug, #aug, None
        compute_importance=True # True by default so not needed
    )
    save_history.append(clf.history["valid_auc"])

assert(np.all(np.array(save_history[0]==np.array(save_history[1]))))
# Out:
# epoch 0  | loss: 0.57776 | train_auc: 0.78953 | valid_auc: 0.80104 |  0:00:01s
# epoch 1  | loss: 0.4741  | train_auc: 0.85843 | valid_auc: 0.86845 |  0:00:02s
# epoch 2  | loss: 0.45059 | train_auc: 0.87337 | valid_auc: 0.88348 |  0:00:03s
# epoch 3  | loss: 0.43497 | train_auc: 0.8908  | valid_auc: 0.89643 |  0:00:04s
# epoch 4  | loss: 0.42716 | train_auc: 0.89811 | valid_auc: 0.90135 |  0:00:05s
# epoch 5  | loss: 0.41261 | train_auc: 0.9061  | valid_auc: 0.90944 |  0:00:07s
# epoch 6  | loss: 0.39464 | train_auc: 0.91141 | valid_auc: 0.91544 |  0:00:08s
# epoch 7  | loss: 0.38969 | train_auc: 0.91788 | valid_auc: 0.92095 |  0:00:09s
# epoch 8  | loss: 0.38398 | train_auc: 0.92066 | valid_auc: 0.92111 |  0:00:10s
# epoch 9  | loss: 0.38027 | train_auc: 0.92119 | valid_auc: 0.92236 |  0:00:12s
# epoch 10 | loss: 0.37562 | train_auc: 0.92498 | valid_auc: 0.92262 |  0:00:13s
# epoch 11 | loss: 0.37409 | train_auc: 0.92717 | valid_auc: 0.92292 |  0:00:14s
# epoch 12 | loss: 0.37504 | train_auc: 0.92821 | valid_auc: 0.92398 |  0:00:15s
# epoch 13 | loss: 0.35996 | train_auc: 0.92726 | valid_auc: 0.9241  |  0:00:16s
# epoch 14 | loss: 0.36747 | train_auc: 0.92988 | valid_auc: 0.92381 |  0:00:18s
# epoch 15 | loss: 0.36514 | train_auc: 0.93077 | valid_auc: 0.92592 |  0:00:19s
# epoch 16 | loss: 0.3584  | train_auc: 0.93078 | valid_auc: 0.92548 |  0:00:20s
# epoch 17 | loss: 0.36318 | train_auc: 0.93142 | valid_auc: 0.92462 |  0:00:21s
# epoch 18 | loss: 0.36245 | train_auc: 0.9326  | valid_auc: 0.92568 |  0:00:22s
# epoch 19 | loss: 0.3637  | train_auc: 0.93259 | valid_auc: 0.9263  |  0:00:23s
# epoch 20 | loss: 0.36058 | train_auc: 0.93208 | valid_auc: 0.92522 |  0:00:25s
# epoch 21 | loss: 0.35644 | train_auc: 0.93345 | valid_auc: 0.92668 |  0:00:26s
# epoch 22 | loss: 0.35831 | train_auc: 0.9339  | valid_auc: 0.92681 |  0:00:27s
# epoch 23 | loss: 0.36176 | train_auc: 0.93377 | valid_auc: 0.92643 |  0:00:28s
# epoch 24 | loss: 0.3552  | train_auc: 0.9354  | valid_auc: 0.92644 |  0:00:29s
# epoch 25 | loss: 0.35704 | train_auc: 0.93527 | valid_auc: 0.92544 |  0:00:30s
# epoch 26 | loss: 0.35412 | train_auc: 0.9354  | valid_auc: 0.92624 |  0:00:31s
# epoch 27 | loss: 0.35326 | train_auc: 0.93608 | valid_auc: 0.9252  |  0:00:33s
# epoch 28 | loss: 0.35479 | train_auc: 0.93484 | valid_auc: 0.92769 |  0:00:34s
# epoch 29 | loss: 0.35652 | train_auc: 0.93459 | valid_auc: 0.92543 |  0:00:35s
# epoch 30 | loss: 0.35538 | train_auc: 0.93673 | valid_auc: 0.92377 |  0:00:36s
# epoch 31 | loss: 0.35797 | train_auc: 0.93625 | valid_auc: 0.92473 |  0:00:37s
# epoch 32 | loss: 0.34968 | train_auc: 0.93762 | valid_auc: 0.92474 |  0:00:39s
# epoch 33 | loss: 0.35159 | train_auc: 0.93803 | valid_auc: 0.9232  |  0:00:40s
# epoch 34 | loss: 0.35144 | train_auc: 0.93623 | valid_auc: 0.92528 |  0:00:41s
# epoch 35 | loss: 0.34918 | train_auc: 0.93849 | valid_auc: 0.92487 |  0:00:42s
# epoch 36 | loss: 0.34984 | train_auc: 0.93809 | valid_auc: 0.92549 |  0:00:43s
# epoch 37 | loss: 0.35102 | train_auc: 0.93859 | valid_auc: 0.92416 |  0:00:44s
# epoch 38 | loss: 0.35272 | train_auc: 0.93952 | valid_auc: 0.92469 |  0:00:45s
# epoch 39 | loss: 0.34767 | train_auc: 0.93754 | valid_auc: 0.92185 |  0:00:47s
# epoch 40 | loss: 0.347   | train_auc: 0.93938 | valid_auc: 0.92638 |  0:00:48s
# epoch 41 | loss: 0.34852 | train_auc: 0.93992 | valid_auc: 0.92406 |  0:00:49s
# epoch 42 | loss: 0.35169 | train_auc: 0.9399  | valid_auc: 0.92302 |  0:00:50s
# epoch 43 | loss: 0.35226 | train_auc: 0.9391  | valid_auc: 0.92246 |  0:00:51s
# epoch 44 | loss: 0.34329 | train_auc: 0.94007 | valid_auc: 0.9223  |  0:00:52s
# epoch 45 | loss: 0.34972 | train_auc: 0.93986 | valid_auc: 0.92246 |  0:00:53s
# epoch 46 | loss: 0.34592 | train_auc: 0.9398  | valid_auc: 0.9244  |  0:00:54s
# epoch 47 | loss: 0.34325 | train_auc: 0.94075 | valid_auc: 0.92254 |  0:00:55s
# epoch 48 | loss: 0.35086 | train_auc: 0.9402  | valid_auc: 0.92025 |  0:00:57s
#
# Early stopping occurred at epoch 48 with best_epoch = 28 and best_valid_auc = 0.92769
# D:\venvs\venv1\Lib\site-packages\pytorch_tabnet\callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# epoch 0  | loss: 0.57776 | train_auc: 0.78953 | valid_auc: 0.80104 |  0:00:01s
# epoch 1  | loss: 0.4741  | train_auc: 0.85843 | valid_auc: 0.86845 |  0:00:02s
# epoch 2  | loss: 0.45059 | train_auc: 0.87337 | valid_auc: 0.88348 |  0:00:03s
# epoch 3  | loss: 0.43497 | train_auc: 0.8908  | valid_auc: 0.89643 |  0:00:04s
# epoch 4  | loss: 0.42716 | train_auc: 0.89811 | valid_auc: 0.90135 |  0:00:05s
# epoch 5  | loss: 0.41261 | train_auc: 0.9061  | valid_auc: 0.90944 |  0:00:06s
# epoch 6  | loss: 0.39464 | train_auc: 0.91141 | valid_auc: 0.91544 |  0:00:07s
# epoch 7  | loss: 0.38969 | train_auc: 0.91788 | valid_auc: 0.92095 |  0:00:08s
# epoch 8  | loss: 0.38398 | train_auc: 0.92066 | valid_auc: 0.92111 |  0:00:10s
# epoch 9  | loss: 0.38027 | train_auc: 0.92119 | valid_auc: 0.92236 |  0:00:11s
# epoch 10 | loss: 0.37562 | train_auc: 0.92498 | valid_auc: 0.92262 |  0:00:12s
# epoch 11 | loss: 0.37409 | train_auc: 0.92717 | valid_auc: 0.92292 |  0:00:13s
# epoch 12 | loss: 0.37504 | train_auc: 0.92821 | valid_auc: 0.92398 |  0:00:14s
# epoch 13 | loss: 0.35996 | train_auc: 0.92726 | valid_auc: 0.9241  |  0:00:15s
# epoch 14 | loss: 0.36747 | train_auc: 0.92988 | valid_auc: 0.92381 |  0:00:16s
# epoch 15 | loss: 0.36514 | train_auc: 0.93077 | valid_auc: 0.92592 |  0:00:17s
# epoch 16 | loss: 0.3584  | train_auc: 0.93078 | valid_auc: 0.92548 |  0:00:19s
# epoch 17 | loss: 0.36318 | train_auc: 0.93142 | valid_auc: 0.92462 |  0:00:20s
# epoch 18 | loss: 0.36245 | train_auc: 0.9326  | valid_auc: 0.92568 |  0:00:21s
# epoch 19 | loss: 0.3637  | train_auc: 0.93259 | valid_auc: 0.9263  |  0:00:22s
# epoch 20 | loss: 0.36058 | train_auc: 0.93208 | valid_auc: 0.92522 |  0:00:23s
# epoch 21 | loss: 0.35644 | train_auc: 0.93345 | valid_auc: 0.92668 |  0:00:24s
# epoch 22 | loss: 0.35831 | train_auc: 0.9339  | valid_auc: 0.92681 |  0:00:25s
# epoch 23 | loss: 0.36176 | train_auc: 0.93377 | valid_auc: 0.92643 |  0:00:26s
# epoch 24 | loss: 0.3552  | train_auc: 0.9354  | valid_auc: 0.92644 |  0:00:28s
# epoch 25 | loss: 0.35704 | train_auc: 0.93527 | valid_auc: 0.92544 |  0:00:29s
# epoch 26 | loss: 0.35412 | train_auc: 0.9354  | valid_auc: 0.92624 |  0:00:30s
# epoch 27 | loss: 0.35326 | train_auc: 0.93608 | valid_auc: 0.9252  |  0:00:31s
# epoch 28 | loss: 0.35479 | train_auc: 0.93484 | valid_auc: 0.92769 |  0:00:32s
# epoch 29 | loss: 0.35652 | train_auc: 0.93459 | valid_auc: 0.92543 |  0:00:33s
# epoch 30 | loss: 0.35538 | train_auc: 0.93673 | valid_auc: 0.92377 |  0:00:34s
# epoch 31 | loss: 0.35797 | train_auc: 0.93625 | valid_auc: 0.92473 |  0:00:35s
# epoch 32 | loss: 0.34968 | train_auc: 0.93762 | valid_auc: 0.92474 |  0:00:36s
# epoch 33 | loss: 0.35159 | train_auc: 0.93803 | valid_auc: 0.9232  |  0:00:37s
# epoch 34 | loss: 0.35144 | train_auc: 0.93623 | valid_auc: 0.92528 |  0:00:39s
# epoch 35 | loss: 0.34918 | train_auc: 0.93849 | valid_auc: 0.92487 |  0:00:40s
# epoch 36 | loss: 0.34984 | train_auc: 0.93809 | valid_auc: 0.92549 |  0:00:41s
# epoch 37 | loss: 0.35102 | train_auc: 0.93859 | valid_auc: 0.92416 |  0:00:42s
# epoch 38 | loss: 0.35272 | train_auc: 0.93952 | valid_auc: 0.92469 |  0:00:43s
# epoch 39 | loss: 0.34767 | train_auc: 0.93754 | valid_auc: 0.92185 |  0:00:44s
# epoch 40 | loss: 0.347   | train_auc: 0.93938 | valid_auc: 0.92638 |  0:00:45s
# epoch 41 | loss: 0.34852 | train_auc: 0.93992 | valid_auc: 0.92406 |  0:00:46s
# epoch 42 | loss: 0.35169 | train_auc: 0.9399  | valid_auc: 0.92302 |  0:00:47s
# epoch 43 | loss: 0.35226 | train_auc: 0.9391  | valid_auc: 0.92246 |  0:00:48s
# epoch 44 | loss: 0.34329 | train_auc: 0.94007 | valid_auc: 0.9223  |  0:00:50s
# epoch 45 | loss: 0.34972 | train_auc: 0.93986 | valid_auc: 0.92246 |  0:00:51s
# epoch 46 | loss: 0.34592 | train_auc: 0.9398  | valid_auc: 0.9244  |  0:00:52s
# epoch 47 | loss: 0.34325 | train_auc: 0.94075 | valid_auc: 0.92254 |  0:00:53s
# epoch 48 | loss: 0.35086 | train_auc: 0.9402  | valid_auc: 0.92025 |  0:00:54s
#
# Early stopping occurred at epoch 48 with best_epoch = 28 and best_valid_auc = 0.92769
# D:\venvs\venv1\Lib\site-packages\pytorch_tabnet\callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# epoch 0  | loss: 0.57776 | train_auc: 0.78953 | valid_auc: 0.80104 |  0:00:01s
# epoch 1  | loss: 0.4741  | train_auc: 0.85843 | valid_auc: 0.86845 |  0:00:02s
# epoch 2  | loss: 0.45059 | train_auc: 0.87337 | valid_auc: 0.88348 |  0:00:03s
# epoch 3  | loss: 0.43497 | train_auc: 0.8908  | valid_auc: 0.89643 |  0:00:04s
# epoch 4  | loss: 0.42716 | train_auc: 0.89811 | valid_auc: 0.90135 |  0:00:05s
# epoch 5  | loss: 0.41261 | train_auc: 0.9061  | valid_auc: 0.90944 |  0:00:06s
# epoch 6  | loss: 0.39464 | train_auc: 0.91141 | valid_auc: 0.91544 |  0:00:07s
# epoch 7  | loss: 0.38969 | train_auc: 0.91788 | valid_auc: 0.92095 |  0:00:08s
# epoch 8  | loss: 0.38398 | train_auc: 0.92066 | valid_auc: 0.92111 |  0:00:10s
# epoch 9  | loss: 0.38027 | train_auc: 0.92119 | valid_auc: 0.92236 |  0:00:11s
# epoch 10 | loss: 0.37562 | train_auc: 0.92498 | valid_auc: 0.92262 |  0:00:12s
# epoch 11 | loss: 0.37409 | train_auc: 0.92717 | valid_auc: 0.92292 |  0:00:13s
# epoch 12 | loss: 0.37504 | train_auc: 0.92821 | valid_auc: 0.92398 |  0:00:14s
# epoch 13 | loss: 0.35996 | train_auc: 0.92726 | valid_auc: 0.9241  |  0:00:15s
# epoch 14 | loss: 0.36747 | train_auc: 0.92988 | valid_auc: 0.92381 |  0:00:16s
# epoch 15 | loss: 0.36514 | train_auc: 0.93077 | valid_auc: 0.92592 |  0:00:17s
# epoch 16 | loss: 0.3584  | train_auc: 0.93078 | valid_auc: 0.92548 |  0:00:18s
# epoch 17 | loss: 0.36318 | train_auc: 0.93142 | valid_auc: 0.92462 |  0:00:19s
# epoch 18 | loss: 0.36245 | train_auc: 0.9326  | valid_auc: 0.92568 |  0:00:20s
# epoch 19 | loss: 0.3637  | train_auc: 0.93259 | valid_auc: 0.9263  |  0:00:22s
# epoch 20 | loss: 0.36058 | train_auc: 0.93208 | valid_auc: 0.92522 |  0:00:23s
# epoch 21 | loss: 0.35644 | train_auc: 0.93345 | valid_auc: 0.92668 |  0:00:24s
# epoch 22 | loss: 0.35831 | train_auc: 0.9339  | valid_auc: 0.92681 |  0:00:25s
# epoch 23 | loss: 0.36176 | train_auc: 0.93377 | valid_auc: 0.92643 |  0:00:26s
# epoch 24 | loss: 0.3552  | train_auc: 0.9354  | valid_auc: 0.92644 |  0:00:27s
# epoch 25 | loss: 0.35704 | train_auc: 0.93527 | valid_auc: 0.92544 |  0:00:28s
# epoch 26 | loss: 0.35412 | train_auc: 0.9354  | valid_auc: 0.92624 |  0:00:29s
# epoch 27 | loss: 0.35326 | train_auc: 0.93608 | valid_auc: 0.9252  |  0:00:30s
# epoch 28 | loss: 0.35479 | train_auc: 0.93484 | valid_auc: 0.92769 |  0:00:31s
# epoch 29 | loss: 0.35652 | train_auc: 0.93459 | valid_auc: 0.92543 |  0:00:32s
# epoch 30 | loss: 0.35538 | train_auc: 0.93673 | valid_auc: 0.92377 |  0:00:34s
# epoch 31 | loss: 0.35797 | train_auc: 0.93625 | valid_auc: 0.92473 |  0:00:35s
# epoch 32 | loss: 0.34968 | train_auc: 0.93762 | valid_auc: 0.92474 |  0:00:36s
# epoch 33 | loss: 0.35159 | train_auc: 0.93803 | valid_auc: 0.9232  |  0:00:37s
# epoch 34 | loss: 0.35144 | train_auc: 0.93623 | valid_auc: 0.92528 |  0:00:38s
# epoch 35 | loss: 0.34918 | train_auc: 0.93849 | valid_auc: 0.92487 |  0:00:39s
# epoch 36 | loss: 0.34984 | train_auc: 0.93809 | valid_auc: 0.92549 |  0:00:40s
# epoch 37 | loss: 0.35102 | train_auc: 0.93859 | valid_auc: 0.92416 |  0:00:41s
# epoch 38 | loss: 0.35272 | train_auc: 0.93952 | valid_auc: 0.92469 |  0:00:42s
# epoch 39 | loss: 0.34767 | train_auc: 0.93754 | valid_auc: 0.92185 |  0:00:43s
# epoch 40 | loss: 0.347   | train_auc: 0.93938 | valid_auc: 0.92638 |  0:00:44s
# epoch 41 | loss: 0.34852 | train_auc: 0.93992 | valid_auc: 0.92406 |  0:00:46s
# epoch 42 | loss: 0.35169 | train_auc: 0.9399  | valid_auc: 0.92302 |  0:00:47s
# epoch 43 | loss: 0.35226 | train_auc: 0.9391  | valid_auc: 0.92246 |  0:00:48s
# epoch 44 | loss: 0.34329 | train_auc: 0.94007 | valid_auc: 0.9223  |  0:00:49s
# epoch 45 | loss: 0.34972 | train_auc: 0.93986 | valid_auc: 0.92246 |  0:00:50s
# epoch 46 | loss: 0.34592 | train_auc: 0.9398  | valid_auc: 0.9244  |  0:00:51s
# epoch 47 | loss: 0.34325 | train_auc: 0.94075 | valid_auc: 0.92254 |  0:00:52s
# epoch 48 | loss: 0.35086 | train_auc: 0.9402  | valid_auc: 0.92025 |  0:00:53s
#
# Early stopping occurred at epoch 48 with best_epoch = 28 and best_valid_auc = 0.92769
# D:\venvs\venv1\Lib\site-packages\pytorch_tabnet\callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# epoch 0  | loss: 0.57776 | train_auc: 0.78953 | valid_auc: 0.80104 |  0:00:01s
# epoch 1  | loss: 0.4741  | train_auc: 0.85843 | valid_auc: 0.86845 |  0:00:02s
# epoch 2  | loss: 0.45059 | train_auc: 0.87337 | valid_auc: 0.88348 |  0:00:03s
# epoch 3  | loss: 0.43497 | train_auc: 0.8908  | valid_auc: 0.89643 |  0:00:04s
# epoch 4  | loss: 0.42716 | train_auc: 0.89811 | valid_auc: 0.90135 |  0:00:05s
# epoch 5  | loss: 0.41261 | train_auc: 0.9061  | valid_auc: 0.90944 |  0:00:06s
# epoch 6  | loss: 0.39464 | train_auc: 0.91141 | valid_auc: 0.91544 |  0:00:07s
# epoch 7  | loss: 0.38969 | train_auc: 0.91788 | valid_auc: 0.92095 |  0:00:09s
# epoch 8  | loss: 0.38398 | train_auc: 0.92066 | valid_auc: 0.92111 |  0:00:10s
# epoch 9  | loss: 0.38027 | train_auc: 0.92119 | valid_auc: 0.92236 |  0:00:11s
# epoch 10 | loss: 0.37562 | train_auc: 0.92498 | valid_auc: 0.92262 |  0:00:12s
# epoch 11 | loss: 0.37409 | train_auc: 0.92717 | valid_auc: 0.92292 |  0:00:13s
# epoch 12 | loss: 0.37504 | train_auc: 0.92821 | valid_auc: 0.92398 |  0:00:14s
# epoch 13 | loss: 0.35996 | train_auc: 0.92726 | valid_auc: 0.9241  |  0:00:16s
# epoch 14 | loss: 0.36747 | train_auc: 0.92988 | valid_auc: 0.92381 |  0:00:17s
# epoch 15 | loss: 0.36514 | train_auc: 0.93077 | valid_auc: 0.92592 |  0:00:18s
# epoch 16 | loss: 0.3584  | train_auc: 0.93078 | valid_auc: 0.92548 |  0:00:20s
# epoch 17 | loss: 0.36318 | train_auc: 0.93142 | valid_auc: 0.92462 |  0:00:21s
# epoch 18 | loss: 0.36245 | train_auc: 0.9326  | valid_auc: 0.92568 |  0:00:22s
# epoch 19 | loss: 0.3637  | train_auc: 0.93259 | valid_auc: 0.9263  |  0:00:23s
# epoch 20 | loss: 0.36058 | train_auc: 0.93208 | valid_auc: 0.92522 |  0:00:24s
# epoch 21 | loss: 0.35644 | train_auc: 0.93345 | valid_auc: 0.92668 |  0:00:25s
# epoch 22 | loss: 0.35831 | train_auc: 0.9339  | valid_auc: 0.92681 |  0:00:27s
# epoch 23 | loss: 0.36176 | train_auc: 0.93377 | valid_auc: 0.92643 |  0:00:28s
# epoch 24 | loss: 0.3552  | train_auc: 0.9354  | valid_auc: 0.92644 |  0:00:29s
# epoch 25 | loss: 0.35704 | train_auc: 0.93527 | valid_auc: 0.92544 |  0:00:30s
# epoch 26 | loss: 0.35412 | train_auc: 0.9354  | valid_auc: 0.92624 |  0:00:31s
# epoch 27 | loss: 0.35326 | train_auc: 0.93608 | valid_auc: 0.9252  |  0:00:33s
# epoch 28 | loss: 0.35479 | train_auc: 0.93484 | valid_auc: 0.92769 |  0:00:34s
# epoch 29 | loss: 0.35652 | train_auc: 0.93459 | valid_auc: 0.92543 |  0:00:35s
# epoch 30 | loss: 0.35538 | train_auc: 0.93673 | valid_auc: 0.92377 |  0:00:36s
# epoch 31 | loss: 0.35797 | train_auc: 0.93625 | valid_auc: 0.92473 |  0:00:37s
# epoch 32 | loss: 0.34968 | train_auc: 0.93762 | valid_auc: 0.92474 |  0:00:39s
# epoch 33 | loss: 0.35159 | train_auc: 0.93803 | valid_auc: 0.9232  |  0:00:40s
# epoch 34 | loss: 0.35144 | train_auc: 0.93623 | valid_auc: 0.92528 |  0:00:41s
# epoch 35 | loss: 0.34918 | train_auc: 0.93849 | valid_auc: 0.92487 |  0:00:42s
# epoch 36 | loss: 0.34984 | train_auc: 0.93809 | valid_auc: 0.92549 |  0:00:43s
# epoch 37 | loss: 0.35102 | train_auc: 0.93859 | valid_auc: 0.92416 |  0:00:44s
# epoch 38 | loss: 0.35272 | train_auc: 0.93952 | valid_auc: 0.92469 |  0:00:45s
# epoch 39 | loss: 0.34767 | train_auc: 0.93754 | valid_auc: 0.92185 |  0:00:47s
# epoch 40 | loss: 0.347   | train_auc: 0.93938 | valid_auc: 0.92638 |  0:00:48s
# epoch 41 | loss: 0.34852 | train_auc: 0.93992 | valid_auc: 0.92406 |  0:00:50s
# epoch 42 | loss: 0.35169 | train_auc: 0.9399  | valid_auc: 0.92302 |  0:00:51s
# epoch 43 | loss: 0.35226 | train_auc: 0.9391  | valid_auc: 0.92246 |  0:00:52s
# epoch 44 | loss: 0.34329 | train_auc: 0.94007 | valid_auc: 0.9223  |  0:00:53s
# epoch 45 | loss: 0.34972 | train_auc: 0.93986 | valid_auc: 0.92246 |  0:00:54s
# epoch 46 | loss: 0.34592 | train_auc: 0.9398  | valid_auc: 0.9244  |  0:00:55s
# epoch 47 | loss: 0.34325 | train_auc: 0.94075 | valid_auc: 0.92254 |  0:00:56s
# epoch 48 | loss: 0.35086 | train_auc: 0.9402  | valid_auc: 0.92025 |  0:00:57s
#
# Early stopping occurred at epoch 48 with best_epoch = 28 and best_valid_auc = 0.92769
# D:\venvs\venv1\Lib\site-packages\pytorch_tabnet\callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
# plot losses
plt.plot(clf.history['loss'])

# %%
# plot auc
plt.plot(clf.history['train_auc'])
plt.plot(clf.history['valid_auc'])

# %%
# plot learning rates
plt.plot(clf.history['lr'])

# %% [markdown]
# ## Predictions

# %%
preds = clf.predict_proba(X_test)
test_auc = roc_auc_score(y_score=preds[:,1], y_true=y_test)


preds_valid = clf.predict_proba(X_valid)
valid_auc = roc_auc_score(y_score=preds_valid[:,1], y_true=y_valid)

print(f"BEST VALID SCORE FOR {dataset_name} : {clf.best_cost}")
print(f"FINAL TEST SCORE FOR {dataset_name} : {test_auc}")
# Out:
# BEST VALID SCORE FOR census-income : 0.9276913700997471
# FINAL TEST SCORE FOR census-income : 0.923995441607089

# %%
# check that best weights are used
assert np.isclose(valid_auc, np.max(clf.history['valid_auc']), atol=1e-6)

# %%
clf.predict(X_test)
# Out:
# array(['not_wealthy', 'wealthy', 'wealthy', ..., 'not_wealthy', 'wealthy',
#        'wealthy'], shape=(3267,), dtype='<U11')

# %% [markdown]
# # Save and load Model

# %%
# save tabnet model
saving_path_name = "./tabnet_model_test_1"
saved_filepath = clf.save_model(saving_path_name)
# Out:
# Successfully saved model at ./tabnet_model_test_1.zip

# %%
# define new model with basic parameters and load state dict weights
loaded_clf = TabNetClassifier()
loaded_clf.load_model(saved_filepath)
# Out:
# D:\venvs\venv1\Lib\site-packages\pytorch_tabnet\abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")

# %%
loaded_preds = loaded_clf.predict_proba(X_test)
loaded_test_auc = roc_auc_score(y_score=loaded_preds[:,1], y_true=y_test)

print(f"FINAL TEST SCORE FOR {dataset_name} : {loaded_test_auc}")
# Out:
# FINAL TEST SCORE FOR census-income : 0.923995441607089

# %%
assert(test_auc == loaded_test_auc)

# %%
loaded_clf.predict(X_test)
# Out:
# array(['not_wealthy', 'wealthy', 'wealthy', ..., 'not_wealthy', 'wealthy',
#        'wealthy'], shape=(3267,), dtype='<U11')

# %% [markdown]
# # Global explainability : feat importance summing to 1

# %%
clf.feature_importances_
# Out:
# array([0.0284343 , 0.0284343 , 0.0284343 , 0.04695162, 0.13404411,
#        0.25778768, 0.06739668, 0.05259316, 0.05566171, 0.05566171,
#        0.05566171, 0.06392961, 0.10904638, 0.01596273])

# %% [markdown]
# # Local explainability and masks

# %%
explain_matrix, masks = clf.explain(X_test)

# %%
fig, axs = plt.subplots(1, 3, figsize=(20,20))


for i in range(3):
    axs[i].imshow(masks[i][:50])
    axs[i].set_title(f"mask {i}")
    axs[i].set_xticklabels(labels = features, rotation=45)
# Out:
# C:\Users\Farshad\AppData\Local\Temp\ipykernel_12800\2446531049.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(labels = features, rotation=45)
# C:\Users\Farshad\AppData\Local\Temp\ipykernel_12800\2446531049.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(labels = features, rotation=45)
# C:\Users\Farshad\AppData\Local\Temp\ipykernel_12800\2446531049.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(labels = features, rotation=45)

# %% [markdown]
# # XGB

# %%
from xgboost import XGBClassifier

clf_xgb = XGBClassifier(max_depth=8,
    learning_rate=0.1,
    n_estimators=1000,
    verbosity=0,
    silent=None,
    objective='binary:logistic',
    booster='gbtree',
    n_jobs=-1,
    nthread=None,
    gamma=0,
    min_child_weight=1,
    max_delta_step=0,
    subsample=0.7,
    colsample_bytree=1,
    colsample_bylevel=1,
    colsample_bynode=1,
    reg_alpha=0,
    reg_lambda=1,
    scale_pos_weight=1,
    base_score=0.5,
    random_state=0,
    seed=None,)

clf_xgb.fit(X_train, y_train,
        eval_set=[(X_valid, y_valid)],
        early_stopping_rounds=40,
        verbose=10)

# %%
preds = np.array(clf_xgb.predict_proba(X_valid))
valid_auc = roc_auc_score(y_score=preds[:,1], y_true=y_valid)
print(valid_auc)

preds = np.array(clf_xgb.predict_proba(X_test))
test_auc = roc_auc_score(y_score=preds[:,1], y_true=y_test)
print(test_auc)
